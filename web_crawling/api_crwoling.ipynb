# %%
import json

data = """
{
    "lastBuildDate": "Thu, 06 May 2021 15:03:07 +0900",
    "total": 543059,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "음성 대소초, '어른 공경의 마음을 키워요'",
            "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2217965",
            "link": "http://www.gukjenews.com/news/articleView.html?idxno=2217965",
            "description": "학생들이 어버이날을 앞두고 행사를 갖고 있다.(제공=음성교육지원청) 충북 음성 대소초등학교(교장 이상국)는 6일 학생자치회에서 어버이날을 앞두고 대소초 <b>어린이</b>들을 위해 도움을 주시고 계신 어르신들께 감사의... ",
            "pubDate": "Thu, 06 May 2021 15:02:00 +0900"
        },
        {
            "title": "[새로나온책] 플로렌스 나이팅게일의 생애와 업적 외",
            "originallink": "http://www.joongboo.com/news/articleView.html?idxno=363484903",
            "link": "http://www.joongboo.com/news/articleView.html?idxno=363484903",
            "description": "이 책에 담은 이야기는 2008~2020년 사이에 글쓴이가 여러 <b>어린이</b>하고 푸름이를 만나서 들려준 말을 바탕으로... 그러던 어느 <b>날</b> 떠돌이 하나가 이 마을을 방문했다. 떠돌이는 오랫동안 세계 여러 나라를 여행했지만 이제는... ",
            "pubDate": "Thu, 06 May 2021 15:02:00 +0900"
        },
        {
            "title": "[명소 탐방] '가로림만·코끼리바위' 품은 충남 서산 황금산에 가보니",
            "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2217901",
            "link": "http://www.gukjenews.com/news/articleView.html?idxno=2217901",
            "description": "'<b>어린이 날</b>'이라 그런지, 아이들을 동반한 가족들이 제법 많았다. 황금산 전 구간을 둘러본다고 가정할 경우 아이들에게는 '위험'한 구간이 제법 많았다. 우리 일행은 해발 156m 황금산 정상에 올라 임경업 사당을 둘러보고... ",
            "pubDate": "Thu, 06 May 2021 15:02:00 +0900"
        },
        {
            "title": "곡성군, <b>어린이날</b> 기념 외국인 인형극 특별 공연",
            "originallink": "https://www.wikitree.co.kr/articles/646156",
            "link": "https://www.wikitree.co.kr/articles/646156",
            "description": "곡성군(군수 유근기)이 <b>어린이날</b>을 기념해 지난 5일부터 곡성섬진강기차마을에서 외국인 인형극... 공연시간은 30분 가량이며 하루 4차례 무대가 열린다.군 관계자는 “이번 공연이 어린이들 뿐만 아니라 가족 모두에게... ",
            "pubDate": "Thu, 06 May 2021 15:00:00 +0900"
        },
        {
            "title": "[뉴스큐브] 신규확진 574명…<b>어린이날</b> 검사건수 감소",
            "originallink": "http://www.yonhapnewstv.co.kr/MYH20210506010700038/?did=1825m",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=422&aid=0000483907",
            "description": "신규확진자가 600명 아래로 떨어졌지만, 휴일 검사 건수 감소 영향이 반영된 것으로 보입니다. 특히 5월 가정의 달을 맞아 각종 모임이 늘어나는 상황에서 울산 등 일부 지역에서는 해외유입 변이 바이러스도 급속도로... ",
            "pubDate": "Thu, 06 May 2021 15:00:00 +0900"
        },
        {
            "title": "부영그룹, '부영 사랑으로 어린이집'에 <b>어린이날</b> 선물",
            "originallink": "http://www.dailysmart.co.kr/news/articleView.html?idxno=44231",
            "link": "http://www.dailysmart.co.kr/news/articleView.html?idxno=44231",
            "description": "국내외 사회공헌 사업에 앞장서온 부영그룹이 <b>어린이날</b>을 맞아 전국 68곳 '부영 사랑으로 어린이집' 원아들에게 하트 모양 티셔츠 2763장을 선물했다. 사진=부영그룹.  국내외 사회공헌 사업에 앞장서온 부영그룹이... ",
            "pubDate": "Thu, 06 May 2021 15:00:00 +0900"
        },
        {
            "title": "대구대 캐릭터 두두, 대구국제마라톤대회 1등차지 상품 기부",
            "originallink": "http://www.breaknews.com/804317",
            "link": "http://www.breaknews.com/804317",
            "description": "대구지역 <b>어린이</b> 시설 등에 기부했다. 대구국제마라톤대회의 도전 부담을 가볍게... ▲ 두두의 대구SOS<b>어린이</b>마을에 치킨 기부 (C) 대구대 캐릭터 마라톤에서 1등을... ",
            "pubDate": "Thu, 06 May 2021 15:00:00 +0900"
        },
        {
            "title": "예스24 5월 1주, ‘주술회전’ 만화-소설 1위 다퉈",
            "originallink": "http://munhaknews.com/?p=45527",
            "link": "http://munhaknews.com/?p=45527",
            "description": "<b>어린이날</b> 맞아 관련 도서 주목…투자관련서 인기도 꾸준 예스24(대표 김석환) 5월 1주 종합 베스트셀러에서... 특징이라면 <b>어린이날</b>을 맞아 어린이 만화 시리즈가 주목받았다. 인기 크리에이터 ‘흔한남매’의 코믹북... ",
            "pubDate": "Thu, 06 May 2021 15:00:00 +0900"
        },
        {
            "title": "송가인, 팬들 사랑 가득한 <b>어린이날</b> 선물 공개",
            "originallink": "http://star.mk.co.kr/new/view.php?mc=ST&year=2021&no=437420",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=009&aid=0004790087",
            "description": "특히 ‘신나는 송가인 <b>어린이날</b>’이라고 적힌 정성스러운 스티커에서 팬들의 송가인 사랑이 듬뿍 묻어난다. 이를 본 누리꾼들은 “과자 파티! 맛있게 먹으면 0칼로리”, “가인제과여라”, “<b>어린이날</b> 선물도... ",
            "pubDate": "Thu, 06 May 2021 14:58:00 +0900"
        },
        {
            "title": "청운대 삼학재 '너나나나'팀, 홍성군 지역아동센터에 '핸드메이드 팔찌' 기부",
            "originallink": "http://www.incheonilbo.com/news/articleView.html?idxno=1093365",
            "link": "http://www.incheonilbo.com/news/articleView.html?idxno=1093365",
            "description": "청운대학교 교육혁신센터의 삼학재에 참여한'너나나나'팀은 <b>어린이날</b>을 맞아 4일 홍성군 지역아동센터 두... 팀장 진성희(호텔경영학과 3) 학생은 &quot;이번 <b>어린이날</b> 기부를 통해 아이들에게 코로나로 힘들었던 기억은... ",
            "pubDate": "Thu, 06 May 2021 14:58:00 +0900"
        }
    ]
}"""
json_data = json.loads(data)
print(json_data['items'][3]['title'])

# for i in 10:
#     print(json_data['items'][i]['title'])
# Out:
# 곡성군, <b>어린이날</b> 기념 외국인 인형극 특별 공연

# %%
import requests
import pprint
import openpyxl


client_id = '865A5lB1n_MbA4ZWJclv'
client_secret = 'VMVpm3HNkP'
start, num = 1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹','제목','링크'])


search = input("검색어를 입력하세요 : ")
display = input("검색 갯수 : ")
# naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query='+search+'&display=100'
# header_params = {"X-naver-client-id":client_id,"X-naver-client-secret":client_secret}
# res = requests.get(naver_open_api, headers=header_params)

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query='+search+'&display='+display
    header_params = {"X-naver-client-id":client_id,"X-naver-client-secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code ==200:
        data = res.json()
        for item in data['items']:
            num+=1
            excel_sheet.append([num,item['title'], item['link']])
    else:
        print("Error Code : " ,res.status_code)

excel_file.save(search +'.xlsx')
excel_file.close()
################첫번째 실행문##################################
# if res.status_code == 200:
#     data = res.json()
#     for index, item in enumerate(data['items']): #'items'의 갯수를 정수화
#         print(index + 1,'.', item['title'],'\n', item['link'])
# else:
#     print("Error Code :", res.status_code)
# Out:
# 검색어를 입력하세요 : 한강
# 검색갯수10

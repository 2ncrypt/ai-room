# %%
import requests
from bs4 import BeautifulSoup

site_list = ['https://finance.naver.com/sise/lastsearch2.nhn']
pinace_n = []
pinace_p = []
for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')

for tag in soup.select('.box_type_l'):
    for p_n in tag.select('tbody tr td a'):
        print(pinace_n.append(p_n.text))
        

# print(soup)
#     items = soup.select('#contentarea > div.box_type_l ')
#     name = soup.select('#contentarea > div.box_type_l > table > tbody > a ')
#     for _ in items:
#         print(_)
    #contentarea > div.box_type_l

# %%
#contentarea > div.box_type_l > table > tbody > tr:nth-child(3) > td:nth-child(2) > a
#contentarea > div.box_type_l > table > tbody > tr:nth-child(4) > td:nth-child(2) > a
#    items = soup.select('#contentarea > div.box_type_l > table > tbody')
#contentarea > div.box_type_l > table > tbody > tr:nth-child(3) > td:nth-child(6) > span

# %%
# import requests
# from bs4 import BeautifulSoup
# res = requests.get('https://finance.naver.com/sise/lastsearch2.nhn')
# soup = BeautifulSoup(res.content,'html.parser')
# while True:
#     a = input('코드 입력 : ')
#     items = soup.select('td {}'.format(a))
#     for item in items:
#        print(item.get_text())
#     if a == 'quit':
#         break

# %%
import lxml
import pandas as pd
df = pd.read_html('https://finance.naver.com/sise/lastsearch2.nhn',encoding='cp949')
df
df[1]
df_jusic = df[1].dropna()
df_jusic
# Out:
#       순위       종목명   검색비율       현재가      전일비      등락률         거래량        시가  \
# 1    1.0       HMM  2.23%   38900.0   3250.0   +9.12%   9775506.0   36250.0
# 2    2.0      삼성전자  1.59%   82000.0    600.0   -0.73%   8295709.0   81700.0
# 3    3.0     삼성중공업  1.54%    6150.0   1010.0  -14.11%  59097257.0    5660.0
# 4    4.0       카카오  1.23%  114000.0   1500.0   -1.30%   1797165.0  115000.0
# 5    5.0      셀트리온  1.04%  252500.0   7500.0   -2.88%    645036.0  260000.0
# 9    6.0      대한항공  0.76%   27400.0   1050.0   +3.98%   3396960.0   26350.0
# 10   7.0      LG전자  0.64%  152500.0   2000.0   -1.29%    716136.0  154000.0
# 11   8.0     POSCO  0.61%  393500.0  17000.0   +4.52%    448082.0  380500.0
# 12   9.0      KB금융  0.59%   56800.0   3500.0   +6.57%   1692548.0   54400.0
# 13  10.0     헬릭스미스  0.57%   31700.0   3000.0  +10.45%    772314.0   28700.0
# 17  11.0    SK하이닉스  0.56%  129500.0   2500.0   -1.89%   2074279.0  130000.0
# ...

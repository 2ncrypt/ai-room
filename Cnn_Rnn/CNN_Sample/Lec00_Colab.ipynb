# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

cd '/content/drive/MyDrive/ai-room/Cnn_Rnn/CNN'
#항상 마운트하고 항상 경로지정 해야함
#import sys
#sys.path.append('drive/My Drive/Colab Notebooks/deepLearningCodes')
#sys.path.append('drive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/DmitryUlyanov/deep-image-prior.git '/content/drive/My Drive/Colab_Notebooks/Research/DIP'
# Out:
# Cloning into '/content/drive/My Drive/Colab_Notebooks/Research/DIP'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289
# Receiving objects: 100% (289/289), 24.28 MiB | 18.31 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# Out:
# drive  sample_data

# %%
# cd '/content/drive/MyDrive/ai-room/Cnn_Rnn/CNN'
# !cp Lec00_Colab.ipynb Colab_Setting.ipynb

# %%
#사용 할 수 있는 GPU 스펙
# !nvidia-smi
# Out:
# Mon May 17 07:31:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # 새 섹션

# %%
import tensorflow as tf


import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

batch_size = 128
num_classes = 10
epochs = 100

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(512, activation='sigmoid',input_shape=(784,)))
model.add(tf.keras.layers.Dense(num_classes, activation='sigmoid'))

model.summary()

sgd = tf.keras.optimizers.SGD(lr=0.1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer=sgd,metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)

score = model.evaluate(x_test, y_test, verbose=0)
print(f'테스트 손실값 : {score[0]}')
print(f'테스트 정확도 : {score[1]}')
# Out:
# Train on 60000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0893 - accuracy: 0.3427
# Epoch 2/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0829 - accuracy: 0.4870
# Epoch 3/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0768 - accuracy: 0.5671
# Epoch 4/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0702 - accuracy: 0.6250
# Epoch 5/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0641 - accuracy: 0.6741
# Epoch 6/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0588 - accuracy: 0.7159
# Epoch 7/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0544 - accuracy: 0.7470
# Epoch 8/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0508 - accuracy: 0.7709
# Epoch 9/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0478 - accuracy: 0.7897
# Epoch 10/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0453 - accuracy: 0.8040
# Epoch 11/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0431 - accuracy: 0.8142
# Epoch 12/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0413 - accuracy: 0.8222
# Epoch 13/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0397 - accuracy: 0.8285
# Epoch 14/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0383 - accuracy: 0.8335
# Epoch 15/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0371 - accuracy: 0.8391
# Epoch 16/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0360 - accuracy: 0.8425
# Epoch 17/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0350 - accuracy: 0.8456
# Epoch 18/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0341 - accuracy: 0.8482
# Epoch 19/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0333 - accuracy: 0.8509
# Epoch 20/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0326 - accuracy: 0.8539
# Epoch 21/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0319 - accuracy: 0.8558
# Epoch 22/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0313 - accuracy: 0.8584
# Epoch 23/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0307 - accuracy: 0.8602
# Epoch 24/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0301 - accuracy: 0.8622
# Epoch 25/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.0296 - accuracy: 0.8636
# Epoch 26/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0292 - accuracy: 0.8644
# Epoch 27/100
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0287 - accuracy: 0.8664
# Epoch 28/100
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0283 - accuracy: 0.8674
# Epoch 29/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0280 - accuracy: 0.8690
# Epoch 30/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0276 - accuracy: 0.8698
# Epoch 31/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0273 - accuracy: 0.8709
# Epoch 32/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0269 - accuracy: 0.8717
# Epoch 33/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0266 - accuracy: 0.8727
# Epoch 34/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0264 - accuracy: 0.8732
# Epoch 35/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0261 - accuracy: 0.8742
# Epoch 36/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0258 - accuracy: 0.8753
# Epoch 37/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0256 - accuracy: 0.8760
# Epoch 38/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0253 - accuracy: 0.8769
# Epoch 39/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0251 - accuracy: 0.8772
# Epoch 40/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0249 - accuracy: 0.8781
# Epoch 41/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0247 - accuracy: 0.8789
# Epoch 42/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0245 - accuracy: 0.8797
# Epoch 43/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0243 - accuracy: 0.8801
# Epoch 44/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0242 - accuracy: 0.8808
# Epoch 45/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0240 - accuracy: 0.8814
# Epoch 46/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0238 - accuracy: 0.8823
# Epoch 47/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0237 - accuracy: 0.8824
# Epoch 48/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0235 - accuracy: 0.8826
# Epoch 49/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0234 - accuracy: 0.8831
# Epoch 50/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0232 - accuracy: 0.8839
# Epoch 51/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0231 - accuracy: 0.8842
# Epoch 52/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0229 - accuracy: 0.8845
# Epoch 53/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0228 - accuracy: 0.8854
# Epoch 54/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0227 - accuracy: 0.8858
# Epoch 55/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0226 - accuracy: 0.8862
# Epoch 56/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0225 - accuracy: 0.8863
# Epoch 57/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0224 - accuracy: 0.8871
# Epoch 58/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0222 - accuracy: 0.8875
# Epoch 59/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0221 - accuracy: 0.8876
# Epoch 60/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0220 - accuracy: 0.8879
# Epoch 61/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0219 - accuracy: 0.8885
# Epoch 62/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0218 - accuracy: 0.8890
# Epoch 63/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0217 - accuracy: 0.8893
# Epoch 64/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0217 - accuracy: 0.8894
# Epoch 65/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0216 - accuracy: 0.8898
# Epoch 66/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0215 - accuracy: 0.8902
# Epoch 67/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0214 - accuracy: 0.8905
# Epoch 68/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0213 - accuracy: 0.8907
# Epoch 69/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0212 - accuracy: 0.8909
# Epoch 70/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0212 - accuracy: 0.8915
# Epoch 71/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0211 - accuracy: 0.8918
# Epoch 72/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0210 - accuracy: 0.8917
# Epoch 73/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0209 - accuracy: 0.8920
# Epoch 74/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0209 - accuracy: 0.8926
# Epoch 75/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0208 - accuracy: 0.8930
# Epoch 76/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0207 - accuracy: 0.8930
# Epoch 77/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0207 - accuracy: 0.8935
# Epoch 78/100
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0206 - accuracy: 0.8934
# Epoch 79/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0205 - accuracy: 0.8939
# Epoch 80/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0205 - accuracy: 0.8939
# Epoch 81/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0204 - accuracy: 0.8943
# Epoch 82/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0203 - accuracy: 0.8943
# Epoch 83/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0203 - accuracy: 0.8946
# Epoch 84/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0202 - accuracy: 0.8951
# Epoch 85/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0202 - accuracy: 0.8951
# Epoch 86/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0201 - accuracy: 0.8953
# Epoch 87/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0200 - accuracy: 0.8956
# Epoch 88/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0200 - accuracy: 0.8959
# Epoch 89/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0199 - accuracy: 0.8960
# Epoch 90/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0199 - accuracy: 0.8962
# Epoch 91/100
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0198 - accuracy: 0.8964
# Epoch 92/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0198 - accuracy: 0.8966
# Epoch 93/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0197 - accuracy: 0.8968
# Epoch 94/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0197 - accuracy: 0.8973
# Epoch 95/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0196 - accuracy: 0.8973
# Epoch 96/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0196 - accuracy: 0.8977
# Epoch 97/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0195 - accuracy: 0.8975
# Epoch 98/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0195 - accuracy: 0.8980
# Epoch 99/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0195 - accuracy: 0.8978
# Epoch 100/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0194 - accuracy: 0.8981
# 테스트 손실값 : 0.018417533815652132
# 테스트 정확도 : 0.9057000279426575

# %% [markdown]
# #epoch20
# 테스트 손실값 : 0.020988858216255905
# 테스트 정확도 : 0.8967999815940857

# %% [markdown]
# #epoch100
# 테스트 손실값 : 0.018417533815652132
# 테스트 정확도 : 0.9057000279426575
